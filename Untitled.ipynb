# %%
import numpy as np
arr = np.array([1,2,3,4,5,6,7])
print("Original array:\n",arr)
# Out:
# Original array:
#  [1 2 3 4 5 6 7]

# %%
print("\n Every other rows:\n",arr[::2])
# Out:
#  Every other rows:
#  [1 3 5 7]

# %%
temp = arr[:2:3]
print("\n Array with first 2 rows and 3 columns:\n",temp)
# Out:
#  Array with first 2 rows and 3 columns:
#  [1]
